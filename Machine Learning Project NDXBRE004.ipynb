# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sn


from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
#from sklearn.model_selection import KFold

#from pathlib import Path
import PIL
from PIL import Image, ImageOps
import os
import glob

import torch
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
#from torch.utils.data import SubsetRandomSampler

#HYPER PARAMS:
BATCH_SIZE = 20
TRAIN_TEST_SIZE = 0.8

# %% [markdown]
# # Data Loading and Pre-processing

# %%
#circle_dir = Path.cwd() / 'circles*'

#spaghetti code to load all image folders

circles = []
for files in glob.iglob('/Users/brennannaidoo/Desktop/Mechatronics Course/Year_4/F/EEE4114F/ML Project/circles/*'):
    circles.append(np.asarray(ImageOps.grayscale(Image.open(files)))) #importing and making images grayscale

squares = []
for files in glob.iglob('/Users/brennannaidoo/Desktop/Mechatronics Course/Year_4/F/EEE4114F/ML Project/squares/*'):
    squares.append(np.asarray(ImageOps.grayscale(Image.open(files)))) #importing and making images grayscale
    
triangles = []
for files in glob.iglob('/Users/brennannaidoo/Desktop/Mechatronics Course/Year_4/F/EEE4114F/ML Project/triangles/*'):
    triangles.append(np.asarray(ImageOps.grayscale(Image.open(files)))) #importing and making images grayscale

pentagons = []
for files in glob.iglob('/Users/brennannaidoo/Desktop/Mechatronics Course/Year_4/F/EEE4114F/ML Project/pentagons/*'):
    im = ImageOps.grayscale(Image.open(files))
    im = im.resize((28,28), resample = PIL.Image.LANCZOS) #resize image to 28/28 using high qualilty downsampler
    pentagons.append(np.asarray(im)) #importing and making images grayscale
    
hexagons = []
for files in glob.iglob('/Users/brennannaidoo/Desktop/Mechatronics Course/Year_4/F/EEE4114F/ML Project/hexagons/*'):
    im = ImageOps.grayscale(Image.open(files))
    im = im.resize((28,28), resample = PIL.Image.LANCZOS) #resize image to 28/28 using high qualilty downsampler
    hexagons.append(np.asarray(im)) #importing and making images grayscale


full_set = np.concatenate((circles,squares,triangles,pentagons,hexagons))
#np.shape(full_set)

#custom label generation
full_set_labels = [] 
for i in range(500):
    if i <= 99:
        full_set_labels.append(0) #circle
    elif i > 99 and i <= 199:
        full_set_labels.append(1) #square
    elif i > 199 and i <=299:
        full_set_labels.append(2) #triangle
    elif i > 299 and i <=399:
        full_set_labels.append(3) #pentagon
    elif i > 399 and i <=499:
        full_set_labels.append(4) #hexagon
        
#print(full_set_labels[299])

x_train, x_eval, y_train, y_eval = train_test_split(full_set, full_set_labels, train_size = TRAIN_TEST_SIZE, shuffle = True)

# %%
#np.shape(triangles)
#print(np.shape(hexagons[0]))
#print(hexagons[0])
#Image.fromarray(hexagons[0]).show()
#Image.fromarray(pentagons[0]).show()
#Image.fromarray(circles[0])

# %% [markdown]
# # Dataset Class Definition

# %%
#frankensteins shape dataset class 
#based on jarryd sons ML lab 2 notebook 
class ShapeSet(Dataset):
    
    def __init__(self, data, targets, transform = None, ):
        
        self.data = data
        self.targets = targets
        self.transform = transform
        self.target_transform = target_transform
        #self.enc = LabelEncoder()
        #targets = self.enc.fit_transform(targets.reshape(-1,))
        #self.targets = torch.LongTensor(targets)
       
        
    def __len__(self):
        
        return len(self.data)
    
    
    def __getitem__(self, index): 
        
        img = self.data[index]
        label = self.targets[index]
        
        if self.transform:
            img = self.transform(img)
            
       # if self.target_transform:
        #    label = self.target_transform(label)
        
        
        return img, label

# %% [markdown]
# # Datasets and Data Loaders

# %%
transform = transforms.ToTensor()
target_transform = transforms.ToTensor()
#scaling ommitted as ToTensor() transform scales pixel values to between 0 and 1

train_dataset = ShapeSet(x_train, y_train, transform = transform)
val_dataset = ShapeSet(x_eval, y_eval, transform = transform)

train_loader = DataLoader(train_dataset, batch_size = BATCH_SIZE) #load batches of input data
val_loader = DataLoader(val_dataset, batch_size = len(val_dataset)) #load all of val data

# %% [markdown]
# # Model Definition

# %%
class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        # 1 input image channel, 1 output channel1, 4x4 square convolution
        # kernel
        self.conv1 = nn.Conv2d(1, 1, 4)
        self.conv2 = nn.Conv2d(1, 1, 4)
        
        self.fc1 = nn.Linear(4 * 4, 120)  # 4*4 from kernel dimension
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 5) #change 5 to x when new classes are needed
        
    def forward(self, x):
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x = torch.flatten(x, 1) # flatten all dimensions except the batch dimension
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net = Net()
#print(net)

# %% [markdown]
# # Training/ Test Loops

# %%
loss_fn = nn.CrossEntropyLoss()
optimiser = optim.Adam(net.parameters(), lr = 0.001)

train_loss = []
#train_acc = []
def train_loop(dataloader, model, loss_fn, optimizer):
    #correct = 0  
    size = len(dataloader.dataset)
    runningLoss = 0.0
    
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)
        #correct += (pred.argmax(1) == y).type(torch.float).sum().item()
        
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        
        optimizer.step()

        
        loss, current = loss.item(), batch * len(X)
        #print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
        #print(batch % 10 )
        runningLoss += loss #sum losses
        if (batch % 10 == 9): #take every 10th batch sample from the zeroth 
            train_loss.append(runningLoss)
            #train_acc.append(correct)  # will scale this when plotting 
            #correct = 0 
            runningLoss = 0.0
        

        
val_acc = []
val_loss = []
#y_pred = []
#y_true = []

def val_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    valid_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            #_,y_pred.extend(torch.max(pred, 1)) #save y pred 
            #y_true.extend(y) # save y true 
            
            valid_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    valid_loss /= num_batches
    correct /= size
    
    val_acc.append(correct*100)
    val_loss.append(valid_loss)
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {valid_loss:>8f} \n")

# %% [markdown]
# # Training:

# %%
EPOCHS = 100
for e in range(EPOCHS):
    print('Starting Ephoch', + e)
    train_loop(train_loader, net, loss_fn, optimiser)
    val_loop(val_loader, net, loss_fn)
print('DONE')
# Out:
# Starting Ephoch 0
# Test Error:
#  Accuracy: 19.0%, Avg loss: 1.610681
#
# Starting Ephoch 1
# Test Error:
#  Accuracy: 17.0%, Avg loss: 1.606942
#
# Starting Ephoch 2
# Test Error:
#  Accuracy: 18.0%, Avg loss: 1.597703
#
# Starting Ephoch 3
# Test Error:
#  Accuracy: 29.0%, Avg loss: 1.568129
#
# Starting Ephoch 4
# Test Error:
#  Accuracy: 43.0%, Avg loss: 1.455550
#
# Starting Ephoch 5
# Test Error:
#  Accuracy: 41.0%, Avg loss: 1.233847
#
# Starting Ephoch 6
# Test Error:
#  Accuracy: 48.0%, Avg loss: 1.036924
#
# Starting Ephoch 7
# Test Error:
#  Accuracy: 64.0%, Avg loss: 0.924617
#
# Starting Ephoch 8
# Test Error:
#  Accuracy: 66.0%, Avg loss: 0.841854
#
# Starting Ephoch 9
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.775636
#
# Starting Ephoch 10
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.723382
#
# Starting Ephoch 11
# Test Error:
#  Accuracy: 66.0%, Avg loss: 0.683849
#
# Starting Ephoch 12
# Test Error:
#  Accuracy: 69.0%, Avg loss: 0.651925
#
# Starting Ephoch 13
# Test Error:
#  Accuracy: 68.0%, Avg loss: 0.626648
#
# Starting Ephoch 14
# Test Error:
#  Accuracy: 69.0%, Avg loss: 0.605329
#
# Starting Ephoch 15
# Test Error:
#  Accuracy: 70.0%, Avg loss: 0.583513
#
# Starting Ephoch 16
# Test Error:
#  Accuracy: 70.0%, Avg loss: 0.566464
#
# Starting Ephoch 17
# Test Error:
#  Accuracy: 70.0%, Avg loss: 0.550875
#
# Starting Ephoch 18
# Test Error:
#  Accuracy: 69.0%, Avg loss: 0.540402
#
# Starting Ephoch 19
# Test Error:
#  Accuracy: 72.0%, Avg loss: 0.529318
#
# Starting Ephoch 20
# Test Error:
#  Accuracy: 73.0%, Avg loss: 0.520044
#
# Starting Ephoch 21
# Test Error:
#  Accuracy: 73.0%, Avg loss: 0.509695
#
# Starting Ephoch 22
# Test Error:
#  Accuracy: 73.0%, Avg loss: 0.501084
#
# Starting Ephoch 23
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.494164
#
# Starting Ephoch 24
# Test Error:
#  Accuracy: 74.0%, Avg loss: 0.486011
#
# Starting Ephoch 25
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.478277
#
# Starting Ephoch 26
# Test Error:
#  Accuracy: 74.0%, Avg loss: 0.471506
#
# Starting Ephoch 27
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.465829
#
# Starting Ephoch 28
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.457929
#
# Starting Ephoch 29
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.451575
#
# Starting Ephoch 30
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.446869
#
# Starting Ephoch 31
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.442554
#
# Starting Ephoch 32
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.436412
#
# Starting Ephoch 33
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.431950
#
# Starting Ephoch 34
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.428224
#
# Starting Ephoch 35
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.423107
#
# Starting Ephoch 36
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.423895
#
# Starting Ephoch 37
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.421657
#
# Starting Ephoch 38
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.418139
#
# Starting Ephoch 39
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.415986
#
# Starting Ephoch 40
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.415876
#
# Starting Ephoch 41
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.415340
#
# Starting Ephoch 42
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.415645
#
# Starting Ephoch 43
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.415800
#
# Starting Ephoch 44
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.417585
#
# Starting Ephoch 45
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.416580
#
# Starting Ephoch 46
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.417043
#
# Starting Ephoch 47
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.418512
#
# Starting Ephoch 48
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.420627
#
# Starting Ephoch 49
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.420899
#
# Starting Ephoch 50
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.424986
#
# Starting Ephoch 51
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.430068
#
# Starting Ephoch 52
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.429097
#
# Starting Ephoch 53
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.424358
#
# Starting Ephoch 54
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.438331
#
# Starting Ephoch 55
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.448472
#
# Starting Ephoch 56
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.434685
#
# Starting Ephoch 57
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.440674
#
# Starting Ephoch 58
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.465677
#
# Starting Ephoch 59
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.461025
#
# Starting Ephoch 60
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.441975
#
# Starting Ephoch 61
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.448834
#
# Starting Ephoch 62
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.455297
#
# Starting Ephoch 63
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.439987
#
# Starting Ephoch 64
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.450622
#
# Starting Ephoch 65
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.445583
#
# Starting Ephoch 66
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.452449
#
# Starting Ephoch 67
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.471453
#
# Starting Ephoch 68
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.452849
#
# Starting Ephoch 69
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.456912
#
# Starting Ephoch 70
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.475903
#
# Starting Ephoch 71
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.459043
#
# Starting Ephoch 72
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.476157
#
# Starting Ephoch 73
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.485126
#
# Starting Ephoch 74
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.471540
#
# Starting Ephoch 75
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.510512
#
# Starting Ephoch 76
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.487083
#
# Starting Ephoch 77
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.492950
#
# Starting Ephoch 78
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.502000
#
# Starting Ephoch 79
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.525562
#
# Starting Ephoch 80
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.535748
#
# Starting Ephoch 81
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.492609
#
# Starting Ephoch 82
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.540770
#
# Starting Ephoch 83
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.547201
#
# Starting Ephoch 84
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.559007
#
# Starting Ephoch 85
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.572055
#
# Starting Ephoch 86
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.581891
#
# Starting Ephoch 87
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.590869
#
# Starting Ephoch 88
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.603255
#
# Starting Ephoch 89
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.609872
#
# Starting Ephoch 90
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.615831
#
# Starting Ephoch 91
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.627229
#
# Starting Ephoch 92
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.670072
#
# Starting Ephoch 93
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.665882
#
# Starting Ephoch 94
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.643370
#
# Starting Ephoch 95
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.698610
#
# Starting Ephoch 96
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.681589
#
# Starting Ephoch 97
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.680607
#
# Starting Ephoch 98
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.663874
#
# Starting Ephoch 99
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.615282
#
# DONE

# %%
fig1 = plt.figure(figsize = (8,8))
training_loss = np.divide(train_loss,10)
plt.plot(training_loss)
plt.xlabel("Mini-Batch")
plt.ylabel("Cross Entropy Loss for Training Set")

'''
fig2 = plt.figure(figsize = (8,8))
training_acc = train_acc * 10 #batchsize = 10 therefore acc = sum (correct)/10 * 100
plt.plot(training_acc)
plt.xlabel("Mini-Batch")
plt.ylabel("Accuracy for Training Set")
'''


#fig2 = fig1 = plt.figure(figsize = (8,8))
#plt.plot(val_hist['val_loss'])
#print( train_loss)
fig3 = plt.figure(figsize = (8,8))
plt.plot(val_loss)
plt.xlabel("Epochs")
plt.ylabel("Cross Entropy Loss for Validation Set")

fig4 = plt.figure(figsize = (8,8))
plt.plot(val_acc)
plt.xlabel("Epochs")
plt.ylabel("Accuracy for Validation Set")
# Out:
# Text(0, 0.5, 'Accuracy for Validation Set')

# %% [markdown]
# # Confusion Matrix

# %%
it = iter(val_loader)
x,y = next(it)
outputs = net(x)
_, y_pred = torch.max(outputs, 1)


#print(cm)
#print(y_pred)

fig5 = plt.figure(figsize = (8,8))
cm = confusion_matrix(y.numpy(),y_pred.numpy(), normalize = 'true')
plt.matshow(cm, fignum = 1)

for(i, j), z in np.ndenumerate(cm):
    plt.text(j,i, '{:0.3f}'.format(z))

plt.xlabel("Predicted Output")
plt.ylabel('True Label')


#plt.gca().set_xticklabels('Circle','Square','Triangle')
#plt.gca().set_yticklabels(classes)
plt.colorbar()
plt.show()

# %% [markdown]
# # Model Save

# %%
#torch.save(net, 'ML_Proj_CNN.pth')

# %% [markdown]
# # Displaying Confusions as a List

# %%
it = iter(val_loader)
x,y = next(it)
outputs = net(x)
_, y_pred = torch.max(outputs, 1)

y = y.numpy()
y_pred = y_pred.numpy()
#print(y_pred)
#print(np.shape(y))

#y_conf = []
#y_pred_conf = []
for i in range(len(y)):
    if y_pred[i] != y[i]:
        #y_conf.append(y[i])
        #y_pred_conf.append(y_pred[i])
        print('Model confuses %1d with %1d' % (y_pred[i], y[i]))
        
#test = [1, 2, 3, 4, 5]
#comp = [1, 1, 1, 1, 5]
        
#for i in range(len(test)):
 #   if comp[i] != test[i]:
  #      print('Model confuses %1d with %1d' % (comp[i], test[i]))
# Out:
# Model confuses 2 with 1
# Model confuses 1 with 2
# Model confuses 0 with 2
# Model confuses 0 with 2
# Model confuses 1 with 2
# Model confuses 2 with 0
# Model confuses 1 with 0
# Model confuses 0 with 2
# Model confuses 0 with 1
# Model confuses 2 with 1
# Model confuses 1 with 2
# Model confuses 1 with 2
# Model confuses 2 with 1
# Model confuses 0 with 1
# Model confuses 2 with 0
